# %% [markdown]
# # Aosta Valley Temperature Prediction — Graph Convolutional Network
# Trains a GCN using a spatial k-NN graph built from station coordinates.
# Subsamples to 8,000 points for computational feasibility.

# %%
import sys
sys.path.append('..')

from src.data.loader import load_config
from src.data.preprocessor import build_pipeline
from src.models.gcn import train_gcn

# %% [markdown]
# ## 1. Load Config and Preprocess Data

# %%
config = load_config('../config.yaml')
station_gdf = build_pipeline(config, base_path='..')
print(f"Dataset ready: {station_gdf.shape[0]:,} rows")

# %% [markdown]
# ## 2. Train GCN

# %%
gcn_result = train_gcn(station_gdf, config)

# %% [markdown]
# ## 3. Result

# %%
import pandas as pd
pd.DataFrame([gcn_result]).set_index('model').style.format({'mse': '{:.4f}', 'mae': '{:.4f}', 'r2': '{:.4f}'})
